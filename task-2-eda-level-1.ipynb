# %% [markdown]
# # DATA ANALYTICS WITH OASIS INFOBYTE
# by Simphiwe Lynette Mahlangu

# %% [markdown]
# **Data Analysis Project**
# * Project Title: Exploratory Data Analysis (EDA) on Retail Sales Data
# * Level 1
#
# **Learning Objectives**
#
# The goal of this project is to perform a data analysis (EDA) to uncover patterns, trends, and insight that can help retail businesses make informed decisions.
#
# **Key concepts and challenges:**
# * Data loading and cleaning
# * Descriptive statistics
# * Time series analysis
# * Customer and product analysis
# * Data visualization
# * Recommendations

# %% [markdown]
# **ABOUT THE DATASET: Nutrition Facts for McDonald's Menu**
#
# The dataset consists of information about the nutritional content of McD's menu items including calaries, fat, sugar, and other important nutrients. According to the company, these facts are verified by reputable sources and are regularly updated by McDonalds.
#
#  **SECTION A: Importing Python Libraries for Analysis**
# 1. Pandas: Data cleaning and analysis
# 2. Numpy: Statistical analysis
# 3. Matplotlib and Seaborn: Data visualization
# 4. Warnings: To filter out warnings

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/nutrition-facts/menu.csv

# %% [markdown]
# **SECTION B: Data Acquisition and Reading Data**
#
# Data cleaning techniques used depend on the case use and type of issues encountered. The data is uploaded using pandas, a tool designed for fast and easy analysis operations. Section B focuses on identifying and fixing irregularities in the data in order to produce accurate data analysis in section C.
#
# **Loading and viewing the data**
#
# * data.shape
# * head() to view the first five rows
# * tail() to view the last five rows

# %%
#Data Acquisition and Reading Data
df_mcD = pd.read_csv('/kaggle/input/nutrition-facts/menu.csv')
df_mcD.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df_mcD.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
df_mcD.shape
# Out:
# (260, 24)

# %% [markdown]
# **Retrive data types**
#
# The dataframe.dtypes() function lets us explore potential information and type mismatch. These can be identified as either object, float, int, bool, and datetime64.

# %%
df_mcD.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %% [markdown]
# **Retrieve statistical description**
#
# Used the describe() method to learn about the distribution of data in each column. This shows if there are mathematical issues that exist in the data.

# %%
df_mcD.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# **Retrieve dataset summary**
#
# The dataframe.info() method provides a concise summary of the dataset.

# %%
df_mcD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# **Dealing with missing values**
#
# * Missing values occur when no data values have been stored for a variable (feature) in an observation. These can be represented as '?', 'Na', or just a blank cell.
# * Replace and drop missing values: this means that the contents along the entire row will be dropped wherever the entity is found to be NaN.

# %%
# Missing or non-numerical values
df_mcD.notnull().sum()
# Out:
# Category                         260
# Item                             260
# Serving Size                     260
# Calories                         260
# Calories from Fat                260
# Total Fat                        260
# Total Fat (% Daily Value)        260
# Saturated Fat                    260
# Saturated Fat (% Daily Value)    260
# Trans Fat                        260
# Cholesterol                      260
# Cholesterol (% Daily Value)      260
# Sodium                           260
# Sodium (% Daily Value)           260
# Carbohydrates                    260
# Carbohydrates (% Daily Value)    260
# Dietary Fiber                    260
# Dietary Fiber (% Daily Value)    260
# Sugars                           260
# Protein                          260
# Vitamin A (% Daily Value)        260
# Vitamin C (% Daily Value)        260
# Calcium (% Daily Value)          260
# Iron (% Daily Value)             260
# dtype: int64

# %%
new_mcData= df_mcD.dropna(subset= ['Category'],axis= 0, inplace= True)
print(new_mcData)
# Out:
# None

# %% [markdown]
# **Duplicated data**
#
# The drop_duplicates() function is used to check and drop repeated data entries from the dataset.

# %%
df_mcD.drop_duplicates()
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# **SECTION B: DATA ANALYSIS**
#
# Using a descriptive analysis, I will be summarizing and exploring the following components of a nutrition facts:
#
# 1. Vitamin A and C
# 2. Sodium count
# 3. Protein and Total Fats
# 4. Carbohydrates (Sugars and Fibers)

# %% [markdown]
# **Exploring the number of categories on McD's menu**
#
# The dataset consists of 9 categories with 260 food items. The barchart below shows us that the **coffee and tea** category has maximum items and salads have the lowest number of items.

# %%
df_mcD['Category'].value_counts().head(10)
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %%
# Bargraph

df_mcD['Category'].value_counts().sort_index().plot(kind= 'bar',title= 'Number of Categories on McDs Menu',figsize = (10,5))
plt.xlabel('Categories')
plt.ylabel('Number of Categories')
plt.show()

# %% [markdown]
# **1. Exploring McD's Vitamin A & C Daily Nutrition Fact per Category**
#
# Vitamins are nutritional substances needed in our diets. Vitamin A is fat-soluble and Vitamin C is water-soluble. Both these vitamins' have antioxidant properties

# %%
#Highest Vitamin A Count

df_mcD.groupby('Category')['Vitamin A (% Daily Value)'].mean().plot(kind='bar')

plt.title('Category with Highest Vitamin A Count')
plt.ylabel('Vitamin A')
plt.show()

# %%
salads = df_mcD[df_mcD.Category == 'Salads']
salads.groupby('Item')['Vitamin A (% Daily Value)'].mean().sort_values()
# Out:
# Item
# Premium Bacon Ranch Salad with Crispy Chicken     100.0
# Premium Bacon Ranch Salad with Grilled Chicken    110.0
# Premium Southwest Salad (without Chicken)         160.0
# Premium Bacon Ranch Salad (without Chicken)       170.0
# Premium Southwest Salad with Crispy Chicken       170.0
# Premium Southwest Salad with Grilled Chicken      170.0
# Name: Vitamin A (% Daily Value), dtype: float64

# %%
beverages = df_mcD[df_mcD.Category == 'Beverages']
beverages.groupby('Item')['Vitamin A (% Daily Value)'].mean().sort_values()
# Out:
# Item
# Diet Dr Pepper (Small)                0.0
# Sprite (Large)                        0.0
# Sprite (Child)                        0.0
# Minute Maid Orange Juice (Small)      0.0
# Minute Maid Orange Juice (Medium)     0.0
# Minute Maid Orange Juice (Large)      0.0
# Minute Maid 100% Apple Juice Box      0.0
# Dr Pepper (Small)                     0.0
# Dr Pepper (Medium)                    0.0
# Dr Pepper (Large)                     0.0
# Dr Pepper (Child)                     0.0
# Sprite (Medium)                       0.0
# Sprite (Small)                        0.0
# Diet Dr Pepper (Large)                0.0
# Diet Dr Pepper (Child)                0.0
# Diet Coke (Small)                     0.0
# Diet Coke (Medium)                    0.0
# Diet Coke (Large)                     0.0
# Diet Coke (Child)                     0.0
# Dasani Water Bottle                   0.0
# Coca-Cola Classic (Small)             0.0
# Coca-Cola Classic (Medium)            0.0
# ...

# %% [markdown]
# Vitamin A, also known as retinol, has several important functions such as ensuring that the immune system works properly, healthy eye vision, and keeping our skins and bodies healthy. The above graph shows us that the salads category has maximun vitamin A count and beverages have the lowest count.

# %%
#Highest Vitamin C Count

df_mcD.groupby('Category')['Vitamin C (% Daily Value)'].mean().plot(kind= 'bar')
plt.title('Vitamin C (% Daily Value) Per Category')
plt.ylabel('Vitamin C')
plt.show()

# %%
ss = df_mcD[df_mcD.Category == 'Snacks & Sides']
ss.groupby('Item')['Vitamin C (% Daily Value)'].mean().sort_values()
# Out:
# Item
# Chipotle BBQ Snack Wrap (Crispy Chicken)        0.0
# Honey Mustard Snack Wrap (Crispy Chicken)       0.0
# Ranch Snack Wrap (Crispy Chicken)               0.0
# Chipotle BBQ Snack Wrap (Grilled Chicken)       2.0
# Honey Mustard Snack Wrap (Grilled Chicken)      2.0
# Ranch Snack Wrap (Grilled Chicken)              2.0
# Fruit 'n Yogurt Parfait                        15.0
# Kids French Fries                              15.0
# Side Salad                                     25.0
# Small French Fries                             30.0
# Medium French Fries                            45.0
# Large French Fries                             70.0
# Apple Slices                                  160.0
# Name: Vitamin C (% Daily Value), dtype: float64

# %%
sal = df_mcD[df_mcD.Category == 'Salads']
sal.groupby('Item')['Vitamin C (% Daily Value)'].mean().sort_values()
# Out:
# Item
# Premium Bacon Ranch Salad with Crispy Chicken     25.0
# Premium Southwest Salad (without Chicken)         25.0
# Premium Bacon Ranch Salad (without Chicken)       30.0
# Premium Bacon Ranch Salad with Grilled Chicken    30.0
# Premium Southwest Salad with Crispy Chicken       30.0
# Premium Southwest Salad with Grilled Chicken      30.0
# Name: Vitamin C (% Daily Value), dtype: float64

# %% [markdown]
# Vitamin C, also known as ascorbic acid, also has several important functions such as protecing and keeping cells healthy; maintaing healthy skin, blood vessels, bones, and cartliage. Lack of vitamin C can lead to scurvy. From the graph above, it is evident that the menu has more vitamin A components than vitamin C, with the Cofee and Tea category having no vitamin C components. From the snacks and sides category, Apple Silces have the highest vitamin C component.

# %% [markdown]
# **2. Which Food Item has Maximum Sodium Content?**
#
# According to research, it is estimated that we need about 500 mg of sodium daily. This is crucial for human bodies to conduct nerve impulses, contract and relax muscles, and maintain the proper balance of water and minerals.

# %%
#Food with the highest sodium content
df_mcD.plot(kind= 'scatter', x= 'Category', y= 'Sodium', figsize=(14,5))
plt.title("Sodium Content")
plt.show()

# %%
df_mcD['Sodium'].describe()
# Out:
# count     260.000000
# mean      495.750000
# std       577.026323
# min         0.000000
# 25%       107.500000
# 50%       190.000000
# 75%       865.000000
# max      3600.000000
# Name: Sodium, dtype: float64

# %%
sodium_min= df_mcD['Sodium'].idxmin()
sodium_max= df_mcD['Sodium'].idxmax()

min_item= df_mcD.at[101, 'Item']
max_item= df_mcD.at[82, 'Item']

print('Item with Lowest Sodium Count:', min_item)
print('Item with Highest Soduim Count:', max_item)
# Out:
# Item with Lowest Sodium Count: Apple Slices
# Item with Highest Soduim Count: Chicken McNuggets (40 piece)

# %% [markdown]
# From the above analysis, we can see that the food with the highest sodium content is Chicken McNuggests (40 piece). Too much sodium intake can lead to highblood pressure, heart disease, stroke, and calcium losses. According to the dataset, 40 pieces of Chicken McNuggets contain a maximum of 3600mg of sodium- which contains far more than our bodies need. Apple slices have the lowest sodium contents.

# %% [markdown]
# **3. What is The Relationship Between Protein and Total Fat?**
#
# Research shows that there is an intimate relationship between protein and fat. Human bodies need protein to maintain and replace tissues and to function and grow. Adults need to eat about 60 grams of protein a day. If more protien is consumed than needed, the body breaks the protein down and stores it components as fat.

# %%
# Relationship Between Protien and Total Fat
plot = sns.jointplot(x= 'Total Fat', y= 'Protein', data= df_mcD)

plt.show()

# %%
min_pt= df_mcD[['Protein','Total Fat']].idxmin()
max_pt= df_mcD[['Protein', 'Total Fat']].idxmax()

max_item= df_mcD.at[82, 'Item']
print('Food item with highest relationship:', max_item)

protein= df_mcD.at[101, 'Item']
print('Food item with minimum protein:', protein)

total_fat = df_mcD.at[100, 'Item']
print('Food item with minimum total fat:', total_fat)
# Out:
# Food item with highest relationship: Chicken McNuggets (40 piece)
# Food item with minimum protein: Apple Slices
# Food item with minimum total fat: Side Salad

# %%
df_mcD.loc[[82, 100, 101]]
# Out:
#            Category                          Item     Serving Size  Calories  \
# 82   Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
# 100  Snacks & Sides                    Side Salad    3.1 oz (87 g)        20
# 101  Snacks & Sides                  Apple Slices    1.2 oz (34 g)        15
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82                1060      118.0                        182           20.0
# 100                  0        0.0                          0            0.0
# 101                  0        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                             101        1.0  ...            118
# 100                              0        0.0  ...              4
# 101                              0        0.0  ...              4
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# ...

# %% [markdown]
# From the above analysis, Chicken McNuggets (40 piece) have the highest relationship between protein and total fat.

# %% [markdown]
# **4. Carbohydrates (sugars and fibers)**
#
# These are one of the three main nutrients found in foods and drinks the body breaks down into glucose for the production of energy. Using a box graph, we explore carbohydrates, sugars and dietary fiber on McD's menu.

# %%
plot = sns.set_style('whitegrid')
ax = sns.boxplot(data= df_mcD[['Carbohydrates','Sugars','Dietary Fiber']])
plt.title('Carbohydrates')
plt.show()

# %%
df_mcD[['Sugars','Carbohydrates', 'Dietary Fiber']].describe()
# Out:
#            Sugars  Carbohydrates  Dietary Fiber
# count  260.000000     260.000000     260.000000
# mean    29.423077      47.346154       1.630769
# std     28.679797      28.252232       1.567717
# min      0.000000       0.000000       0.000000
# 25%      5.750000      30.000000       0.000000
# 50%     17.500000      44.000000       1.000000
# 75%     48.000000      60.000000       3.000000
# max    128.000000     141.000000       7.000000

# %%
max_c= df_mc[['Sugars', 'Carbohydrates', 'Dietary Fiber']].idxmax()

max_c1= df_mcD.at[253, 'Item']
max_c2= df_mcD.at[249, 'Item']
max_c3= df_mcD.at[32, 'Item']

print('Max sugar count:', max_c1)
print('Max carbohydrates count:', max_c2)
print('Max dierty fiber:', max_c3)

min_c= df_mcD[['Sugars','Carbohydrates','Dietary Fiber']].idxmin()

min_c1= df_mcD.at[38, 'Item']
min_c2= df_mcD.at[114, 'Item']
min_c3= df_mcD.at[101, 'Item']

print('Min sugar count:', min_c1)
print('Min carbohydrates count:', min_c2)
print('Min dietary fiber:', min_c3)
# Out:
# Max sugar count: McFlurry with M&M’s Candies (Medium)
# Max carbohydrates count: Chocolate Shake (Large)
# Max dierty fiber: Big Breakfast with Hotcakes (Large Biscuit)
# Min sugar count: Hash Brown
# Min carbohydrates count: Diet Coke (Small)
# Min dierty fiber: Apple Slices

# %%
df_mcD.groupby('Category')['Carbohydrates (% Daily Value)'].sum().plot(kind= 'pie')
plt.title('Carbohydrates Per Category')
plt.ylabel('Category')

plt.show()

# %% [markdown]
# From the above, we identified food items with minimum and maximum counts of carbohydrates, suagr, and dietary fiber. On the McDonald's dataset, Carbohydrates (% Daily Value) refers to a combination of these nutrition facts and based on the above pie chart, we can conclude that the McD's menu consists of low carb foods.
